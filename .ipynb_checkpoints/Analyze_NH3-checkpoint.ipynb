# %%
import os
import glob
import itertools
from random import randint
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from pathlib import Path
import time

import matplotlib.cm as cm
from IPython.display import Image
import git

from rmgpy.molecule import Molecule
from rmgpy.data.base import Database

# %% [markdown]
# ## Inputs

# %%
rmg_model_path = '../ammonia/'
analysis_path = '../ammonia_analysis/NH3_results'

# %% [markdown]
# ## Git-python: checkout master branch

# %%
import git
repo = git.Repo(rmg_model_path)
date = time.localtime(repo.head.commit.committed_date)
git_date = f"{date[0]}_{date[1]}_{date[2]}_{date[3]}{date[4]}"
git_sha = str(repo.head.commit)[0:6]
git_msg = str(repo.head.commit.message)[0:50].replace(" ", "_").replace("'", "_").replace("\n", "")

current_commit = f"{git_date}_{git_sha}_{git_msg}"

current_commit
# Out:
# '2021_6_5_1819_463449_master_523K_O088N006'

# %% [markdown]
# ## checkout 1 commit back

# %%
# repo.git.checkout('HEAD^1')
# sha = str(repo.head.commit)
# msg = str(repo.head.commit.message)
# print(sha,': ', msg)

# %% [markdown]
# ## checkout 2 commits back

# %%
# repo = git.Repo('/work/westgroup/lee.ting/cantera/ammonia/')
# repo.git.checkout('HEAD^1')
# sha = repo.head.commit
# msg = repo.head.commit.message
# print(sha,': ', msg)

# %% [markdown]
# ## Read in data
# get a list of the commit folders in this repo

# %%
commit_list = []

# read in each filename into dictionary. 
for path in Path(analysis_path).rglob('*.csv'):
    path_str = str(path)
    start_index = path_str.find(analysis_path)
    
    if start_index != -1:
        commit = path_str[(start_index+len(analysis_path)):]
        print(commit)
        if "\n" in commit:
            end_char = commit.index("\n")
        else: 
            end_char = commit.index("/")
        
        commit = commit[:end_char]
        if commit not in commit_list:
            commit_list.append(commit)
        
print(commit_list)
# Out:
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_011111111111111112.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_012222222222222223.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_013333333333333332.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_014444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_015555555555555555.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_016666666666666666.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_017777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_01888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_021111111111111112.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_022222222222222223.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_02333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_024444444444444442.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_025555555555555554.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_026666666666666665.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_027777777777777776.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_028888888888888888.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03111111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03222222222222222.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_034444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_035555555555555556.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03666666666666667.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_03888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04111111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_042222222222222223.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_043333333333333335.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_044444444444444446.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04555555555555556.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04666666666666667.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_04888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_051111111111111114.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_052222222222222225.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05333333333333334.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05444444444444445.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05555555555555556.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05666666666666667.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_05888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_060000000000000005.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_061111111111111116.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06222222222222223.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06333333333333332.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06555555555555555.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06666666666666667.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06777777777777777.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_06999999999999999.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07111111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07222222222222222.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07555555555555556.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07666666666666666.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_07888888888888888.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_0811111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08222222222222221.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08444444444444443.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08555555555555555.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08666666666666666.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08777777777777777.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_08888888888888888.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_0911111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09222222222222222.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09333333333333332.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09555555555555555.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09666666666666666.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09777777777777777.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09888888888888889.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_09999999999999999.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10111111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10222222222222221.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10444444444444444.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10555555555555556.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10666666666666666.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10777777777777778.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_10888888888888888.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_1111111111111111.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11222222222222222.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11333333333333333.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11444444444444445.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11555555555555555.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11666666666666665.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11777777777777777.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_11888888888888888.csv
# /2021_6_5_1819_463449_master_523K_O088N006/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.11e-07_energy_off_temp_598_O2_0_NH3_0_12.csv
# ['']

# %% [markdown]
# #### Read last line from each CSV file to get the outlet concentrations from the PFR, if "one_commit" is true, only run the master commit

# %%
data_dict = {}

# if one_commit is true, runs analysis on current commit only
one_commit = False
if one_commit == True:
    commit_list = [current_commit]
    
for commit in commit_list:
    first_file = True
    for path in Path('../ammonia_analysis/NH3_results').rglob('*.csv'):
        path_str = str(path)
        if os.stat(path_str).st_size >= 1e6:
            if first_file == True: 
                data = pd.read_csv(path_str)
                aggdata = data.tail(1)
                first_file = False
            else: 
                data = pd.read_csv(path_str)
                aggdata = aggdata.append(data.tail(1))
            data_dict.update({commit:aggdata})
        else:
            print(path_str)

# %% [markdown]
# ## Reproduce plots from Rebrov
#
# Rebrov, E. V., De Croon, M. H. J. M., & Schouten, J. C. (2002). Development of the kinetic model of platinum catalyzed ammonia oxidation in a microreactor. Chemical Engineering Journal, 90(1–2), 61–76. https://doi.org/10.1016/S1385-8947(02)00068-2
#
#
# for reference:
#
# ### $conversion(\%) = \frac{moles\_fed - moles\_out}{moles\_fed} $
#
# ### $selectivity(\%, N_2) = \frac{(2*r_{L6}+r_{L13})100}{r_{L5}} $
#
# ### $selectivity(\%, N_{2}O) = \frac{(2*r_{L7}-r_{L13})100}{r_{L5}} $

# %%
Image('Images/Rebrov_table2.png')

# %% [markdown]
# ### Figure 3

# %% [markdown]
# ### create partial pressure, selectivity, and concentration columns in the dataframe

# %% [markdown]
# #### choose species

# %%
# species partial pressures (for X-axis of plots)
x_axis_nh3 = ['NH3(6)']

conversion_species = ['NH3(6)']
selectivity_species = ['N2(4)','N2O(7)','NO(5)']
# this is H-site adsorption. no way to tell that from cantera 
coverage_species_1 = ['OX(10)', 'HOX(13)', 'X(1)'] 

# this is N-site adsorption. no way to tell that from cantera
#coverage_species_2 = ['NOX(27)', 'NX(59)', 'H3NX(29)', 'X(1)']
coverage_species_2 = ['NO_ads(27)', 'N_ads(64)', 'H3NX(29)', 'X(1)']

# %%
# for commit in commit_list:
#     for i in conversion_species:
#         data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']

# #comment out, since NH3(6) partial pressure (atm) here is the same as X_nh3 initial
# # for commit in commit_list:
# #     data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325

# for commit in commit_list:
#     data_dict[commit]['O2(2) partial pressure (atm)'] =  data_dict[commit]['X_o2 initial']*(data_dict[commit]['P (Pa)']/101325)
#     data_dict[commit]['O2(2) partial pressure (atm)'] = data_dict[commit]['O2(2) partial pressure (atm)'].round(decimals=2)

# for commit in commit_list:
#     for i in selectivity_species:
#         data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
#         selectivity = data_dict[commit][f'{i} Selectivity (%)']

# %%
for commit in commit_list:
    for i in conversion_species:
        data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
    
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])

    for i in coverage_species_1:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
    
    for i in coverage_species_2:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(64)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])

# %%
data_dict[commit].to_csv("rebrov_NH3_data.csv")
data_dict[commit]
# Out:
#       Distance (mm)  T (K)    P (Pa)     V (M^3/s)  X_nh3 initial  \
# 1000            9.0    598  101325.0  2.771000e-08       0.011111
# 1000            9.0    598  101325.0  2.771000e-08       0.012222
# 1000            9.0    598  101325.0  2.771000e-08       0.013333
# 1000            9.0    598  101325.0  2.771000e-08       0.014444
# 1000            9.0    598  101325.0  2.771000e-08       0.015556
# ...             ...    ...       ...           ...            ...
# 1000            9.0    598  101325.0  2.771000e-08       0.115556
# 1000            9.0    598  101325.0  2.771000e-08       0.116667
# 1000            9.0    598  101325.0  2.771000e-08       0.117778
# 1000            9.0    598  101325.0  2.771000e-08       0.118889
# 1000            9.0    598  101325.0  2.771000e-08       0.120000
#
#       X_o2 initial  X_he initial  (NH3/O2)  T (K) final          Rtol  ...  \
# 1000          0.88      0.108889  0.012626        598.0  1.000000e-11  ...
# 1000          0.88      0.107778  0.013889        598.0  1.000000e-11  ...
# 1000          0.88      0.106667  0.015152        598.0  1.000000e-11  ...
# 1000          0.88      0.105556  0.016414        598.0  1.000000e-11  ...
# 1000          0.88      0.104444  0.017677        598.0  1.000000e-11  ...
# ...            ...           ...       ...          ...           ...  ...
# 1000          0.88      0.004444  0.131313        598.0  1.000000e-11  ...
# 1000          0.88      0.003333  0.132576        598.0  1.000000e-11  ...
# 1000          0.88      0.002222  0.133838        598.0  1.000000e-11  ...
# 1000          0.88      0.001111  0.135101        598.0  1.000000e-11  ...
# 1000          0.88      0.000000  0.136364        598.0  1.000000e-11  ...
#
#       O2(2) partial pressure (atm) N2(4) Selectivity (%)  \
# 1000                          0.88             49.861495
# 1000                          0.88             49.847686
# 1000                          0.88             49.833886
# 1000                          0.88             49.820093
# 1000                          0.88             49.806308
# ...                            ...                   ...
# 1000                          0.88             48.596112
# 1000                          0.88             48.582996
# 1000                          0.88             48.569887
# 1000                          0.88             48.556784
# 1000                          0.88             48.543689
#
#      N2O(7) Selectivity (%)  NO(5) Selectivity (%)  OX(10) Coverage  \
# 1000                    0.0           2.667552e-06         0.999500
# 1000                    0.0           2.363825e-06         0.999465
# 1000                    0.0           2.122430e-06         0.999431
# 1000                    0.0           1.926422e-06         0.999398
# 1000                    0.0           1.764383e-06         0.999367
# ...                     ...                    ...              ...
# 1000                    0.0           2.709979e-07         0.997896
# 1000                    0.0           2.689658e-07         0.997885
# 1000                    0.0           2.669693e-07         0.997873
# 1000                    0.0           2.650073e-07         0.997861
# 1000                    0.0           2.630789e-07         0.997850
#
#       HOX(13) Coverage  X(1) Coverage  NO_ads(27) Coverage  \
# 1000      2.673187e-09       0.006432             0.993546
# 1000      2.867248e-09       0.006695             0.993282
# 1000      3.053587e-09       0.006933             0.993042
# 1000      3.232977e-09       0.007151             0.992824
# 1000      3.406087e-09       0.007351             0.992622
# ...                ...            ...                  ...
# 1000      1.210930e-08       0.012562             0.987366
# 1000      1.218071e-08       0.012592             0.987336
# 1000      1.225188e-08       0.012621             0.987306
# 1000      1.232282e-08       0.012651             0.987276
# 1000      1.239353e-08       0.012680             0.987246
#
#       N_ads(64) Coverage  H3NX(29) Coverage
# 1000            0.000017           0.000005
# 1000            0.000018           0.000005
# 1000            0.000019           0.000006
# 1000            0.000019           0.000006
# 1000            0.000020           0.000007
# ...                  ...                ...
# 1000            0.000032           0.000040
# 1000            0.000032           0.000040
# 1000            0.000032           0.000040
# 1000            0.000032           0.000041
# 1000            0.000032           0.000041
#
# [99 rows x 123 columns]

# %%
# ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2(4) Selectivity (%)',
#                                      label='N2',color="orange")
# ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2O(7) Selectivity (%)',
#                                      label='N2O',color='g', ax=ax1)
# ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NO(5) Selectivity (%)',
#                                      label='NO',color='blue', ax=ax1)
# ax1.set_xlabel("NH3(6) partial pressure (atm)")
# ax1.set_ylabel("Selectivity (%)")
# plt.show()

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='N2(4) Selectivity (%)',
                                     label='N2',color="orange")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N2O(7) Selectivity (%)',
                                     label='N2O',color='g', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='NO(5) Selectivity (%)',
                                     label='NO',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Selectivity (%)")
plt.show()

# %%
data_dict[commit].plot.scatter(x='X_nh3 initial',y='NH3(6) conversion (%)',label='NH3(6) conversion (%)',color="r")
# Out:
# <AxesSubplot:xlabel='X_nh3 initial', ylabel='NH3(6) conversion (%)'>

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
        selectivity = data_dict[commit][f'{i} Selectivity (%)']
        print(selectivity)
# Out:
# 1000    49.751244
# 1000    49.627792
# 1000    49.504950
# 1000    49.382716
# 1000    49.261084
#           ...
# 1000    49.028205
# 1000    48.899749
# 1000    48.780482
# 1000    48.661795
# 1000    48.543685
# Name: N2(4) Selectivity (%), Length: 116, dtype: float64
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
#        ...
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# Name: N2O(7) Selectivity (%), Length: 116, dtype: float64
# 1000    8.623474e-08
# 1000    7.827234e-08
# 1000    7.398438e-08
# 1000    7.124887e-08
# 1000    6.932246e-08
#             ...
# 1000    1.466004e-05
# 1000    1.286029e-05
# 1000    1.143953e-05
# 1000    1.029474e-05
# 1000    9.352290e-06
# Name: NO(5) Selectivity (%), Length: 116, dtype: float64

# %%
df_498K = data_dict[commit][data_dict[commit]['T (K)'] == 498]
df_523K = data_dict[commit][data_dict[commit]['T (K)'] == 523]
df_548K = data_dict[commit][data_dict[commit]['T (K)'] == 548]
df_573K = data_dict[commit][data_dict[commit]['T (K)'] == 573]
df_598K = data_dict[commit][data_dict[commit]['T (K)'] == 598]
df_623K = data_dict[commit][data_dict[commit]['T (K)'] == 623]
df_648K = data_dict[commit][data_dict[commit]['T (K)'] == 648]
df_698K = data_dict[commit][data_dict[commit]['T (K)'] == 698]
# Out:
#       Distance (mm)  T (K)    P (Pa)     V (M^3/s)  X_nh3 initial  \
# 1000       8.982018    698  101325.0  2.771000e-08           0.01
# 1000       8.982018    698  101325.0  2.771000e-08           0.02
# 1000       8.982018    698  101325.0  2.771000e-08           0.03
# 1000       8.982018    698  101325.0  2.771000e-08           0.04
# 1000       8.982018    698  101325.0  2.771000e-08           0.05
# 1000       8.982018    698  101325.0  2.771000e-08           0.06
# 1000       8.982018    698  101325.0  2.771000e-08           0.07
# 1000       8.982018    698  101325.0  2.771000e-08           0.08
# 1000       8.982018    698  101325.0  2.771000e-08           0.09
# 1000       8.982018    698  101325.0  2.771000e-08           0.10
# 1000       8.982018    698  101325.0  2.771000e-08           0.11
# 1000       8.982018    698  101325.0  2.771000e-08           0.12
#
#       X_o2 initial  X_he initial  (NH3/O2)  T (C) final          Rtol  ...  \
# 1000          0.88          0.11  0.011364        698.0  1.000000e-11  ...
# 1000          0.88          0.10  0.022727        698.0  1.000000e-11  ...
# 1000          0.88          0.09  0.034091        698.0  1.000000e-11  ...
# 1000          0.88          0.08  0.045455        698.0  1.000000e-11  ...
# 1000          0.88          0.07  0.056818        698.0  1.000000e-11  ...
# 1000          0.88          0.06  0.068182        698.0  1.000000e-11  ...
# 1000          0.88          0.05  0.079545        698.0  1.000000e-11  ...
# 1000          0.88          0.04  0.090909        698.0  1.000000e-11  ...
# 1000          0.88          0.03  0.102273        698.0  1.000000e-11  ...
# 1000          0.88          0.02  0.113636        698.0  1.000000e-11  ...
# 1000          0.88          0.01  0.125000        698.0  1.000000e-11  ...
# 1000          0.88          0.00  0.136364        698.0  1.000000e-11  ...
#
#       NH3(6) + 2 X(1) <=> H2NX(28) + HX(9) ROP [kmol/m^2 s]  \
# 1000                                       4.005802e-11
# 1000                                       1.193121e-10
# 1000                                       1.934927e-10
# 1000                                       2.561043e-10
# 1000                                       3.083726e-10
# 1000                                       3.523781e-10
# 1000                                       3.898852e-10
# 1000                                       4.233709e-10
# 1000                                       4.504395e-10
# 1000                                       4.752420e-10
# 1000                                       4.972169e-10
# 1000                                       5.168047e-10
#
#      H3NX(29) + X(1) <=> H2NX(28) + HX(9) ROP [kmol/m^2 s]  \
# 1000                                       3.766053e-14
# 1000                                       1.121715e-13
# 1000                                       1.819127e-13
# 1000                                       2.407774e-13
# 1000                                       2.899178e-13
# 1000                                       3.312898e-13
# 1000                                       3.665524e-13
# 1000                                       3.980341e-13
# 1000                                       4.234827e-13
# 1000                                       4.468009e-13
# 1000                                       4.674606e-13
# 1000                                       4.858761e-13
#
#      H2NX(28) + X(1) <=> HX(9) + NH_ads(51) ROP [kmol/m^2 s]  \
# 1000                                       5.048174e-14
# 1000                                       1.495592e-13
# 1000                                       2.416171e-13
# 1000                                       3.188283e-13
# 1000                                       3.829136e-13
# 1000                                       4.365741e-13
# 1000                                       4.820696e-13
# 1000                                       5.224961e-13
# 1000                                       5.549669e-13
# 1000                                       5.845908e-13
# 1000                                       6.107024e-13
# 1000                                       6.338560e-13
#
#       NH_ads(51) + X(1) <=> HX(9) + N_ads(64) ROP [kmol/m^2 s]  \
# 1000                                       3.251370e-14
# 1000                                       9.686734e-14
# 1000                                       1.571081e-13
# 1000                                       2.079559e-13
# 1000                                       2.504052e-13
# 1000                                       2.861456e-13
# 1000                                       3.166102e-13
# 1000                                       3.438103e-13
# 1000                                       3.658007e-13
# 1000                                       3.859521e-13
# 1000                                       4.038084e-13
# 1000                                       4.197273e-13
#
#       HNOX(67) + X(1) <=> HX(9) + NO_ads(27) ROP [kmol/m^2 s]  \
# 1000                                       1.042131e-21
# 1000                                       3.103688e-21
# 1000                                       5.033060e-21
# 1000                                       6.661600e-21
# 1000                                       8.021343e-21
# 1000                                       9.166451e-21
# 1000                                       1.014282e-20
# 1000                                       1.101484e-20
# 1000                                       1.172021e-20
# 1000                                       1.236684e-20
# 1000                                       1.294012e-20
# 1000                                       1.345148e-20
#
#       HNOX(67) + OX(10) <=> HX(9) + NO2JX(74) ROP [kmol/m^2 s]  \
# 1000                                       1.713350e-16
# 1000                                       3.534716e-16
# 1000                                       4.862056e-16
# 1000                                       5.840575e-16
# 1000                                       6.587003e-16
# 1000                                       7.174008e-16
# 1000                                       7.646996e-16
# 1000                                       8.049593e-16
# 1000                                       8.358940e-16
# 1000                                       8.631491e-16
# 1000                                       8.862955e-16
# 1000                                       9.060668e-16
#
#       NH3(6) partial pressure (atm)  N2(4) Selectivity (%)  \
# 1000                           0.01              49.875201
# 1000                           0.02              49.751204
# 1000                           0.03              49.627768
# 1000                           0.04              49.504934
# 1000                           0.05              49.382703
# 1000                           0.06              49.261074
# 1000                           0.07              49.140041
# 1000                           0.08              49.028205
# 1000                           0.09              48.899749
# 1000                           0.10              48.780482
# 1000                           0.11              48.661795
# 1000                           0.12              48.543685
#
#       N2O(7) Selectivity (%)  NO(5) Selectivity (%)
# 1000                     0.0               0.000222
# 1000                     0.0               0.000081
# 1000                     0.0               0.000047
# 1000                     0.0               0.000033
# 1000                     0.0               0.000025
# 1000                     0.0               0.000020
# 1000                     0.0               0.000017
# 1000                     0.0               0.000015
# 1000                     0.0               0.000013
# 1000                     0.0               0.000011
# 1000                     0.0               0.000010
# 1000                     0.0               0.000009
#
# [12 rows x 115 columns]

# %%
fig = plt.figure()
ax = plt.axes()
#plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
plt.plot(df_698K['X_nh3 initial'], df_698K['N2(4) Selectivity (%)'], label = 'N2')
plt.plot(df_698K['X_nh3 initial'], df_698K['N2O(7) Selectivity (%)'], label = 'N2O')
plt.plot(df_698K['X_nh3 initial'], 1e5*df_698K['NO(5) Selectivity (%)'], label = 'NO')
plt.xlabel('NH3')
plt.ylabel('Selectivity')
plt.title('X_NH3 v.s. Selectivity Plot ')
plt.legend()

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    
selectivity_species = [df_698K['NO(5) Selectivity (%)'],df_698K['N2O(7) Selectivity (%)'],df_698K['N2(4) Selectivity (%)']]

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    nh3_pressure = data_dict[commit][f'NH3(6) partial pressure (atm)']

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
        selectivity = data_dict[commit][f'{i} Selectivity (%)']
        print(selectivity[0:108])
#         fig, ax = plt.subplots(len(selectivity),1,figsize=(10,30), constrained_layout = True)
#         color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
            
#         for p,j in enumerate(selectivity):
#             data_dict[commit][(data_dict[commit][f'{i} Selectivity (%)'] == j) &
#                              (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
#                                                                                  y=selectivity[0:3], 
#                                                                                  label='NH3(6) conversion (%)', 
#                                                                                  ax=ax[p], 
#                                                                                  color="r")

#             ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')
# Out:
# 1000    49.751244
# 1000    49.627792
# 1000    49.504950
# 1000    49.382716
# 1000    49.261084
#           ...
# 1000    49.028205
# 1000    48.899749
# 1000    48.780482
# 1000    48.661795
# 1000    48.543685
# Name: N2(4) Selectivity (%), Length: 107, dtype: float64
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
#        ...
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# Name: N2O(7) Selectivity (%), Length: 107, dtype: float64
# 1000    8.623474e-08
# 1000    7.827234e-08
# 1000    7.398438e-08
# 1000    7.124887e-08
# 1000    6.932246e-08
#             ...
# 1000    1.466004e-05
# 1000    1.286029e-05
# 1000    1.143953e-05
# 1000    1.029474e-05
# 1000    9.352290e-06
# Name: NO(5) Selectivity (%), Length: 107, dtype: float64

# %% [markdown]
# #### Selectivity and Coverage

# %%
for commit in commit_list:
    data_dict[commit]['NO selectivity (%)'] = 100*(data_dict[commit]['NO(5)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['NO selectivity (%)'])
    no_selectivity = data_dict[commit]['NO selectivity (%)'] 

    data_dict[commit]['N2O selectivity (%)'] = 100*(data_dict[commit]['N2O(7)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['N2O selectivity (%)'])
    n2o_selectivity = data_dict[commit]['N2O selectivity (%)']

    data_dict[commit]['N2 selectivity (%)'] = 100*(data_dict[commit]['N2(4)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['N2 selectivity (%)'])
    n2_selectivity = data_dict[commit]['N2 selectivity (%)']

    S_N2 = n2_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100
    S_NO = no_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100
    S_N2O = n2o_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100

# %%
plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
plt.plot(nh3_pressure[0:11], 1e8*no_selectivity[0:11],label= "NO*e5")
plt.plot(nh3_pressure[0:11], 1e8*n2o_selectivity[0:11],label= "N2O*e5")
plt.plot(nh3_pressure[0:11], n2_selectivity[0:11],label= "N2")
plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
plt.ylabel('Selectivity (%)',fontsize=15)
plt.minorticks_on()
plt.title('Temperature = 498K' ,fontsize=15)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5df8abbef28e> in <module>
#       1 plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
# ----> 2 plt.plot(nh3_pressure[0:11], 1e8*no_selectivity[0:11],label= "NO*e5")
#       3 plt.plot(nh3_pressure[0:11], 1e8*n2o_selectivity[0:11],label= "N2O*e5")
#       4 plt.plot(nh3_pressure[0:11], n2_selectivity[0:11],label= "N2")
#       5 plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
#
# NameError: name 'nh3_pressure' is not defined

# %%
plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
plt.plot(nh3_pressure[0:11], 1e5*no_selectivity[96:107],label= "NO*e5")
plt.plot(nh3_pressure[0:11], 1e5*n2o_selectivity[96:107],label= "N2O*e5")
plt.plot(nh3_pressure[0:11], n2_selectivity[96:107],label= "N2")
plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
plt.ylabel('Selectivity (%)',fontsize=15)
plt.minorticks_on()
plt.title('Temperature = 698K' ,fontsize=15)
plt.legend()

# %% [markdown]
# #### NH3 initial partial pressure

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    nh3_pressure = data_dict[commit][f'NH3(6) partial pressure (atm)']

# %%
nh3_pressure
# Out:
# 1000    0.02
# 1000    0.03
# 1000    0.04
# 1000    0.05
# 1000    0.06
#         ...
# 1000    0.08
# 1000    0.09
# 1000    0.10
# 1000    0.11
# 1000    0.12
# Name: NH3(6) partial pressure (atm), Length: 107, dtype: float64

# %%
for i in selectivity_species:
    data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    print(data_dict[commit][f'{i} Selectivity (%)'])
# Out:
# 1000    49.751244
# 1000    49.627792
# 1000    49.504950
# 1000    49.382716
# 1000    49.261084
#           ...
# 1000    49.028205
# 1000    48.899749
# 1000    48.780482
# 1000    48.661795
# 1000    48.543685
# Name: N2(4) Selectivity (%), Length: 107, dtype: float64
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
#        ...
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# Name: N2O(7) Selectivity (%), Length: 107, dtype: float64
# 1000    8.623474e-08
# 1000    7.827234e-08
# 1000    7.398438e-08
# 1000    7.124887e-08
# 1000    6.932246e-08
#             ...
# 1000    1.466004e-05
# 1000    1.286029e-05
# 1000    1.143953e-05
# 1000    1.029474e-05
# 1000    9.352290e-06
# Name: NO(5) Selectivity (%), Length: 107, dtype: float64

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])    
        selectivityNO = data_dict[commit][f'{i} Selectivity (%)']#.unique()
        selectivityN2O = data_dict[commit][f'{i+1} Selectivity (%)']
       # print(selectivity)
        plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
        plt.plot(nh3_pressure[0:10], selectivityNO[0:10],nh3_pressure[0:10], selectivityN2O[0:10])
        plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
        plt.ylabel(f'{i} Selectivity (%)',fontsize=15)
        plt.minorticks_on()
        plt.grid(b=True, which='minor', color='beige', alpha=0.8, ls='-', lw=1)
        plt.title(f'{commit} \ntemperature {temp}',fontsize=15)
        plt.show()

#         fig, ax = plt.subplots(len(temp),1,figsize=(10,30), constrained_layout = True)

#         # make a list of markers
#         color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
    
#         for p,j in enumerate(selectivity):
#             data_dict[commit][(data_dict[commit][f'{i} Selectivity (%)'] == j) &
#                              (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', y=selectivity, label= f'{i} Selectivity (%)', ax=ax[p], color="r")

#             ax[p].set_title(f'{commit} \ntemperature {temp}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3bd13717e440> in <module>
#       3         data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
#       4         selectivityNO = data_dict[commit][f'{i} Selectivity (%)']#.unique()
# ----> 5         selectivityN2O = data_dict[commit][f'{i+1} Selectivity (%)']
#       6        # print(selectivity)
#       7         plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
for commit in commit_list:
    
    for temp in temps:
        # get keys for O2 (X_o2 initial)
        o2_ratio = data_dict[commit_list[0]]['O2(2) partial pressure (atm)'].unique()

        # set figure size 
        fig, ax = plt.subplots(len(o2_ratio),1,figsize=(10,30), constrained_layout = True)

        # make a list of markers
        color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
    
        for p,j in enumerate(o2_ratio):
            data_dict[commit][(data_dict[commit]['O2(2) partial pressure (atm)'] == j) &
                             (data_dict[commit]['T (C)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                 y='NH3(6) conversion (%)', 
                                                                                 label='NH3(6) conversion (%)', 
                                                                                 ax=ax[p], 
                                                                                 color="r")

            ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')

# %%
for commit in commit_list:
    for m in x_axis_nh3:
        temps = data_dict[commit_list[0]]['T (K)'].unique()
       # print(temps)
        for i in selectivity_species:
            data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
            #print(data_dict[commit][f'{i} Selectivity (%)'])
            for temp in temps:
                Selectivity1 = data_dict[commit][i]
                #print(f'{i} Selectivity (%) is {Selectivity1} at T = {temp}')
                for p,j in enumerate(Selectivity1):
                    data_dict[commit][(data_dict[commit][i] == j) &
                                 (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                     y=Selectivity1, 
                                                                                     label='Selectivity(%)', 
                                                                                     ax=ax[p], 
                                                                                     color="r")

                    ax[p].set_title(f'{commit} \nmole Selectivity {i} = {j} \ntemperature {temp}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-8380998e55ff> in <module>
#      15                                                                                      label='Selectivity(%)',
#      16                                                                                      ax=ax[p],
# ---> 17                                                                                      color="r")
#      18
#      19                     ax[p].set_title(f'{commit} \nmole Selectivity {i} = {j} \ntemperature {temp}')
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1611             ...                       colormap='viridis')
#    1612         """
# -> 1613         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1614
#    1615     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     892         if kind in self._dataframe_kinds:
#     893             if isinstance(data, ABCDataFrame):
# --> 894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
#     896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1010         scatter = ax.scatter(
#    1011             data[x].values,
# -> 1012             data[y].values,
#    1013             c=c_values,
#    1014             label=label,
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([0.00018915905639807119, 0.00022457413935150742,\n              0.00024778626023020143,  0.0002642709378084195,\n               0.0002766180455709284,   0.000286228658293318,\n              0.00029393184846925166, 0.00030025123518933564,\n               0.0003055344458896611, 0.00031002160787221524,\n              ...\n                 0.00987549050495128,   0.014343714992602119,\n                  0.0189351386496281,   0.023592924481496573,\n                0.028286693178647536,   0.032999071312277056,\n                0.037717865476575234,    0.04243692157818962,\n                 0.04715089513718092,    0.05185627623811077],\n             dtype='float64', length=107)] are in the [columns]"

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
        #print(data_dict[commit][f'{i} Selectivity (%)'])
        for temp in temps:
            Selectivity1 = data_dict[commit][i]
            print(f'{i} Selectivity (%)temp,Selectivity1')
# Out:
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2(4) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# N2O(7) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1
# NO(5) Selectivity (%)temp,Selectivity1

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
       # print(data_dict[commit][f'{i} Selectivity (%)'])
        for temp in temps:
            Selectivity1 = data_dict[commit][i]

            # set figure size 
            fig, ax = plt.subplots(len(Selectivity1),1,figsize=(10,30), constrained_layout = True)

            # make a list of markers
            color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}

            for p,j in enumerate(Selectivity1):
                data_dict[commit][(data_dict[commit][i] == j) &
                                 (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                     y=Selectivity1, 
                                                                                     label='Selectivity(%)', 
                                                                                     ax=ax[p], 
                                                                                     color="r")

                ax[p].set_title(f'{commit} \nmole Selectivity {i} = {j} \ntemperature {temp}')
        
    for z in coverage_species_1:
        data_dict[commit][f'{z} Coverage'] = 100*(data_dict[commit][z])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
       # print(data_dict[commit][f'{z} Coverage'])
    
    for k in coverage_species_2:
        data_dict[commit][f'{k} Coverage'] = 100*(data_dict[commit][k])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
       # print(data_dict[commit][f'{k} Coverage'])

# %%
for commit in commit_list:
    
    for temp in temps:
        Selectivity = data_dict[commit]['X_nh3 initial']

        # set figure size 
        fig, ax = plt.subplots(len(X_nh3),1,figsize=(10,30), constrained_layout = True)

        # make a list of markers
        color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
    
        for p,j in enumerate(X_nh3):
            data_dict[commit][(data_dict[commit]['X_nh3 initial'] == j) &
                             (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                 y='Selectivity (%)', 
                                                                                 label='Selectivity(%)', 
                                                                                 ax=ax[p], 
                                                                                 color="r")

            ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-46fce021d6d3> in <module>
#       5
#       6         # set figure size
# ----> 7         fig, ax = plt.subplots(len(X_nh3),1,figsize=(10,30), constrained_layout = True)
#       8
#       9         # make a list of markers
#
# NameError: name 'X_nh3' is not defined

# %% [markdown]
# #### O2 partial pressure

# %%
for commit in commit_list:
    data_dict[commit]['O2(2) partial pressure (atm)'] =  data_dict[commit]['X_o2 initial']*(data_dict[commit]['P (Pa)']/101325)
    data_dict[commit]['O2(2) partial pressure (atm)'] = data_dict[commit]['O2(2) partial pressure (atm)'].round(decimals=2)

# %%
data_dict[commit]['O2(2) partial pressure (atm)']
# Out:
# 1000    0.88
# 1000    0.88
# 1000    0.88
# 1000    0.88
# 1000    0.88
#         ...
# 1000    0.88
# 1000    0.88
# 1000    0.88
# 1000    0.88
# 1000    0.88
# Name: O2(2) partial pressure (atm), Length: 107, dtype: float64

# %% [markdown]
# ### plot

# %% [markdown]
# #### get a list of temperatures used

# %%
for i in x_axis_nh3:
    temps = data_dict[commit_list[0]]['T (K)'].unique()
print(temps)
# Out:
# [498 523 548 573 598 623 648 673 698]

# %%
for commit in commit_list:
    
    for temp in temps:
        # get keys for O2 (X_o2 initial)
        o2_ratio = data_dict[commit_list[0]]['O2(2) partial pressure (atm)'].unique()

        # set figure size 
        fig, ax = plt.subplots(len(o2_ratio),1,figsize=(10,30), constrained_layout = True)

        # make a list of markers
        color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
    
        for p,j in enumerate(o2_ratio):
            data_dict[commit][(data_dict[commit]['O2(2) partial pressure (atm)'] == j) &
                             (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                 y='NH3(6) conversion (%)', 
                                                                                 label='NH3(6) conversion (%)', 
                                                                                 ax=ax[p], 
                                                                                 color="r")

            ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-f011e8022001> in <module>
#      16                                                                                  y='NH3(6) conversion (%)',
#      17                                                                                  label='NH3(6) conversion (%)',
# ---> 18                                                                                  ax=ax[p],
#      19                                                                                  color="r")
#      20
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
df_t_225_02_0_88_data_dict=data_dict[commit][(data_dict[commit]['O2(2) partial pressure (atm)'] == 0.88) &
                             (data_dict[commit]['T (C)'] == 225)]

# %%
df_t_225_02_0_88_data_dict
# Out:
#      Distance (mm)  T (C)    P (Pa)     V (M^3/s)  X_nh3 initial  \
# 921         8280.0    225  101325.0  2.715500e-08          0.010
# 235         2106.0    225  101325.0  2.715500e-08          0.020
# 420         3771.0    225  101325.0  2.715500e-08          0.025
# 98           873.0    225  101325.0  2.715500e-08          0.070
#
#      X_o2 initial  X_he initial  (NH3/O2)  T (C) final          Rtol  ...  \
# 921          0.88         0.110  0.011364        225.0  1.000000e-08  ...
# 235          0.88         0.100  0.022727        225.0  1.000000e-08  ...
# 420          0.88         0.095  0.028409        225.0  1.000000e-08  ...
# 98           0.88         0.050  0.079545        225.0  1.000000e-08  ...
#
#      HNOX(136) + NO2X2(466) <=> NO_X(26) + SX(146) ROP [kmol/m^2 s]  \
# 921                                      -5.168881e-72
# 235                                       1.829502e-59
# 420                                       2.851775e-47
# 98                                        1.661289e-72
#
#     SX(146) + X(1) <=> HOX(13) + NOX2(132) ROP [kmol/m^2 s].1  \
# 921                                       3.417907e-61
# 235                                      -2.670272e-57
# 420                                       1.011025e-50
# 98                                        0.000000e+00
#
#     N_X(25) + SX(146) <=> HNOX(136) + NOX2(132) ROP [kmol/m^2 s].2  \
# 921                                       2.962649e-47
# 235                                      -3.464858e-43
# 420                                       1.509520e-36
# 98                                        0.000000e+00
#
#      N_X(25) + SX(146) <=> HNOX(136) + NOX2(132) ROP [kmol/m^2 s].3  \
# 921                                       2.962649e-47
# 235                                      -3.464858e-43
# 420                                       1.509520e-36
# 98                                        0.000000e+00
#
#      NO2(30) + 2 X(1) <=> NO2X2(248) ROP [kmol/m^2 s]  \
# 921                                      6.222660e-58
# 235                                     -3.819620e-65
# 420                                      2.184174e-54
# 98                                      -7.709948e-74
#
#      NO2X2(248) + OX(10) <=> NOX2(132) + O2X(731) ROP [kmol/m^2 s]  \
# 921                                       4.630594e-58
# 235                                      -2.691550e-66
# 420                                       4.229134e-55
# 98                                        3.998287e-70
#
#      NH3(6) conversion (%)  NO(5) selectivity (%)  \
# 921           2.585369e-06           1.515396e-29
# 235          -1.309972e-05          -5.140747e-38
# 420          -2.642432e-06          -5.146292e-36
# 98           -1.745461e-07          -4.312019e-35
#
#      NH3(6) partial pressure (atm)  O2(2) partial pressure (atm)
# 921                          0.010                          0.88
# 235                          0.020                          0.88
# 420                          0.025                          0.88
# 98                           0.070                          0.88
#
# [4 rows x 465 columns]

# %%
df_t_225_02_0_88_data_dict.plot.scatter(x='NH3(6) partial pressure (atm)', 
                                        y='NH3(6) conversion (%)', 
                                        label='NH3(6) conversion (%)', 
                                        color="r")
# Out:
# <AxesSubplot:xlabel='NH3(6) partial pressure (atm)', ylabel='NH3(6) conversion (%)'>
