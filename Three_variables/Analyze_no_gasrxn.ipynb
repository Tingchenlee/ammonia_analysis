# %%
import os
import glob
import itertools
from random import randint
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from pathlib import Path
import time

import matplotlib.cm as cm
from IPython.display import Image
import git

from rmgpy.molecule import Molecule
from rmgpy.data.base import Database

# %%
#Input file
rmg_model_path = '../../ammonia/'
analysis_path = '../Three_variables/results/no_gasrxn_results'

# %%
#Git-python: checkout master branch
import git
repo = git.Repo(rmg_model_path)
date = time.localtime(repo.head.commit.committed_date)
git_date = f"{date[0]}_{date[1]}_{date[2]}_{date[3]}{date[4]}"
git_sha = str(repo.head.commit)[0:6]
git_msg = str(repo.head.commit.message)[0:50].replace(" ", "_").replace("'", "_").replace("\n", "")

current_commit = f"{git_date}_{git_sha}_{git_msg}"

current_commit
# Out:
# '2021_6_16_232_27a89a_13_reactions'

# %%
# #checkout 1 commit back
# repo.git.checkout('HEAD^1')
# sha = str(repo.head.commit)
# msg = str(repo.head.commit.message)
# print(sha,': ', msg)

# #checkout 2 commit back
# repo = git.Repo('/work/westgroup/lee.ting/cantera/ammonia/')
# repo.git.checkout('HEAD^1')
# sha = repo.head.commit
# msg = repo.head.commit.message
# print(sha,': ', msg)

# %%
commit_list = []

# read in each filename into dictionary. get a list of the commit folders in this repo
for path in Path(analysis_path).rglob('*.csv'):
    path_str = str(path)
    start_index = path_str.find(analysis_path)
    
    if start_index != -1:
        commit = path_str[(start_index+len(analysis_path)):]
        print(commit)
        if "\n" in commit:
            end_char = commit.index("\n")
        else: 
            end_char = commit.index("/")
        
        commit = commit[:end_char]
        if commit not in commit_list:
            commit_list.append(commit)
        
print(commit_list)
# Out:
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/1000/results/Spinning_basket_area_6.6e-05_energy_off_temp_1000_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_013793103448275862.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_017586206896551725.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_02137931034482759.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_02517241379310345.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_02896551724137931.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_032758620689655175.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_036551724137931035.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_040344827586206895.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_04413793103448276.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_04793103448275862.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_05172413793103448.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_05551724137931035.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_05931034482758621.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_06310344827586206.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_06689655172413793.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_0706896551724138.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_07448275862068965.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_07827586206896552.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_08206896551724137.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_08586206896551724.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_0896551724137931.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_09344827586206896.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_09724137931034482.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_10103448275862069.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_10482758620689654.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_10862068965517241.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_11241379310344828.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_11620689655172413.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.3e-05_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_6.6e-05_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_12.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_02.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_03.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_04.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_05.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_06.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_066.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_07.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_08.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_09.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_1.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_11.csv
# /2021_6_16_232_27a89a_13_reactions/Reactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_12.csv
# ['']

# %%
data_dict = {}

# Read last line from each CSV file to get the outlet concentrations from the PFR
# if "one_commit" is true, only run the master commit 
one_commit = False
if one_commit == True:
    commit_list = [current_commit]
    
for commit in commit_list:
    first_file = True
    for path in Path(f"../Three_variables/results/no_gasrxn_results/{current_commit}").rglob('*.csv'):
        path_str = str(path)
        if os.stat(path_str).st_size >= 1e6:
            if first_file == True: 
                data = pd.read_csv(path_str)
                aggdata = data.tail(1)
                first_file = False
            else: 
                data = pd.read_csv(path_str)
                aggdata = aggdata.append(data.tail(1))
            data_dict.update({commit:aggdata})
        else:
            print(path_str)
# Out:
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/ConstPressureReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_3.88e-07_energy_off_temp_598_O2_0_NH3_0_07.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_02.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_03.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_04.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_05.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_06.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_066.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_07.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_08.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_09.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_1.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_11.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_2.77e+34_energy_off_temp_598_O2_0_NH3_0_12.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_02.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_03.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_04.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_05.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_06.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_066.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_07.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_08.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_09.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_1.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_11.csv
# ../Three_variables/results/no_gasrxn_results/2021_6_16_232_27a89a_13_reactions/IdealGasReactor/energy_off/sensitivity_off/700/results/Spinning_basket_area_6.6e-05_energy_off_temp_700_O2_0_NH3_0_12.csv

# %% [markdown]
# ## Reproduce plots from Rebrov
#
# Rebrov, E. V., De Croon, M. H. J. M., & Schouten, J. C. (2002). Development of the kinetic model of platinum catalyzed ammonia oxidation in a microreactor. Chemical Engineering Journal, 90(1–2), 61–76. https://doi.org/10.1016/S1385-8947(02)00068-2
#
#
# for reference:
#
# ### $conversion(\%) = \frac{moles\_fed - moles\_out}{moles\_fed} $
#
# ### $selectivity(\%, N_2) = \frac{(2*r_{L6}+r_{L13})100}{r_{L5}} $
#
# ### $selectivity(\%, N_{2}O) = \frac{(2*r_{L7}-r_{L13})100}{r_{L5}} $

# %% [markdown]
# # For our selectivity definitions
# Two types of selectivity. Overall, and instantaneous.
#
# For overall selectivity, it depends on the total amounts exiting the packed bed. Probably what is measured experimentally from the PBR experiment (by measuring concentrations leaving the bed).
#
# $$ selectivity(N2) = \frac{2 * moles_{N2}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# The 2 is because we are preserving (and counting) atoms of Nitrogen. Selectivity is "What percentage of N atoms (from consuming ammonia) ended up as N2?
# "
#
# $$ selectivity(N2O) = \frac{2 * moles_{N2O}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# $$ selectivity(NO) = \frac{moles_{NO}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
#
#
# For instantaneous selectivity, it changes at different points in the packed bed.
# If we want the instantaneous selectivity evaluated at the exit of the bed, evaluate these expressions at the end of the bed (the last row):
#
# $$ selectivity(N2)  = \frac{ 2 * net rate of production of N2}{-1 * net rate of production of NH3}$$
# $$ selectivity(N2O)  = \frac{ 2 * net rate of production of N2O}{-1 * net rate of production of NH3}$$
# $$ selectivity(NO)  = \frac{  net rate of production of NO}{-1 * net rate of production of NH3}$$

# %%
Image('Images/Rebrov_table2.png')

# %% [markdown]
# ### Figure 3
# #### create partial pressure, selectivity, and concentration columns in the dataframe

# %%
for commit in commit_list:
    data_dict[commit]['NH3(6) conversion (%)']= 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])/data_dict[commit]['X_nh3 initial']
    
    S_N2 = ((-2)*(data_dict[commit]['N2(4) ROP [kmol/m^3 s]']+data_dict[commit]['N2(4) surface ROP [kmol/m^2 s]'])/
            (data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']+ data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']))

    S_NO = ((-1)*(data_dict[commit]['NO(5) ROP [kmol/m^3 s]']+data_dict[commit]['NO(5) surface ROP [kmol/m^2 s]'])/
            (data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']+ data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']))

    S_N2O = ((-2)*(data_dict[commit]['N2O(7) ROP [kmol/m^3 s]']+data_dict[commit]['N2O(7) surface ROP [kmol/m^2 s]'])/
            (data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']+ data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']))
    
    data_dict[commit]['N2(4) Selectivity (%)'] = 100*S_N2 / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['NO(5) Selectivity (%)'] = 100*S_NO / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['N2O(7) Selectivity (%)'] = 100*S_N2O / (S_N2 + S_NO + S_N2O)

    data_dict[commit]['OX Coverage']=data_dict[commit]['OX']/(data_dict[commit]['OX'] + data_dict[commit]['OHX']+ data_dict[commit]['X(1)'])
    data_dict[commit]['OHX Coverage']=data_dict[commit]['OHX']/(data_dict[commit]['OX'] + data_dict[commit]['OHX']+ data_dict[commit]['X(1)'])
    data_dict[commit]['X(1) Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['OX'] + data_dict[commit]['OHX']+ data_dict[commit]['X(1)'])
    data_dict[commit]['NOX Coverage']=data_dict[commit]['NOX']/(data_dict[commit]['NOX'] + data_dict[commit]['NX']+ data_dict[commit]['NH3X']+ data_dict[commit]['X(1)'])
    data_dict[commit]['NX Coverage']=data_dict[commit]['NX']/(data_dict[commit]['NOX'] + data_dict[commit]['NX']+ data_dict[commit]['NH3X']+ data_dict[commit]['X(1)'])
    data_dict[commit]['NH3X Coverage']=data_dict[commit]['NH3X']/(data_dict[commit]['NOX'] + data_dict[commit]['NX']+ data_dict[commit]['NH3X']+ data_dict[commit]['X(1)'])
    data_dict[commit]['X Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['NOX'] + data_dict[commit]['NX']+ data_dict[commit]['NH3X']+ data_dict[commit]['X(1)'])

# %%
data_dict[commit].to_csv("rebrov_no_gasrxn_data.csv")
data_dict[commit]
# Out:
#       Distance (mm)  T (K)    P (Pa)  V (M^3/s)  X_nh3 initial  X_o2 initial  \
# 1000            9.0    598  101325.0   0.000058           0.02          0.88
# 1000            9.0    598  101325.0   0.000058           0.03          0.88
# 1000            9.0    598  101325.0   0.000058           0.04          0.88
# 1000            9.0    598  101325.0   0.000058           0.05          0.88
# 1000            9.0    598  101325.0   0.000058           0.06          0.88
# ...             ...    ...       ...        ...            ...           ...
# 1000            9.0    598  101325.0   0.000058           0.08          0.88
# 1000            9.0    598  101325.0   0.000058           0.09          0.88
# 1000            9.0    598  101325.0   0.000058           0.10          0.88
# 1000            9.0    598  101325.0   0.000058           0.11          0.88
# 1000            9.0    598  101325.0   0.000058           0.12          0.88
#
#       X_he initial  (NH3/O2)  T (K) final          Rtol  ...  \
# 1000          0.10  0.022727        598.0  1.000000e-11  ...
# 1000          0.09  0.034091        598.0  1.000000e-11  ...
# 1000          0.08  0.045455        598.0  1.000000e-11  ...
# 1000          0.07  0.056818        598.0  1.000000e-11  ...
# 1000          0.06  0.068182        598.0  1.000000e-11  ...
# ...            ...       ...          ...           ...  ...
# 1000          0.04  0.090909        598.0  1.000000e-11  ...
# 1000          0.03  0.102273        598.0  1.000000e-11  ...
# 1000          0.02  0.113636        598.0  1.000000e-11  ...
# 1000          0.01  0.125000        598.0  1.000000e-11  ...
# 1000          0.00  0.136364        598.0  1.000000e-11  ...
#
#       N2(4) Selectivity (%) NO(5) Selectivity (%) N2O(7) Selectivity (%)  \
# 1000           1.015939e-08            100.000000           7.767285e-08
# 1000           1.978817e-08            100.000000           1.513039e-07
# 1000           3.288532e-08            100.000000           2.514727e-07
# 1000           4.956203e-08            100.000000           3.790346e-07
# 1000           6.986443e-08             99.999999           5.343702e-07
# ...                     ...                   ...                    ...
# 1000           1.214327e-07             99.999999           9.290084e-07
# 1000           1.527173e-07             99.999999           1.168465e-06
# 1000           1.876685e-07             99.999998           1.436068e-06
# 1000           2.262947e-07             99.999998           1.731845e-06
# 1000           2.685956e-07             99.999998           2.055815e-06
#
#       OX Coverage  OHX Coverage  X(1) Coverage  NOX Coverage  NX Coverage  \
# 1000          1.0  5.053723e-13   4.000242e-08      0.012581     0.000804
# 1000          1.0  7.053112e-13   5.194380e-08      0.018731     0.001197
# 1000          1.0  9.092397e-13   6.474261e-08      0.024789     0.001584
# 1000          1.0  1.116217e-12   7.805864e-08      0.030759     0.001965
# 1000          1.0  1.325276e-12   9.169692e-08      0.036642     0.002340
# ...           ...           ...            ...           ...          ...
# 1000          1.0  1.747212e-12   1.195349e-07      0.048154     0.003075
# 1000          1.0  1.959380e-12   1.336252e-07      0.053787     0.003434
# 1000          1.0  2.172068e-12   1.477883e-07      0.059341     0.003788
# 1000          1.0  2.385147e-12   1.620060e-07      0.064816     0.004137
# 1000          1.0  2.598528e-12   1.762653e-07      0.070215     0.004481
#
#       NH3X Coverage  X Coverage
# 1000       0.001853    0.984762
# 1000       0.002758    0.977314
# 1000       0.003650    0.969977
# 1000       0.004528    0.962748
# 1000       0.005394    0.955624
# ...             ...         ...
# 1000       0.007087    0.941684
# 1000       0.007915    0.934864
# 1000       0.008731    0.928140
# 1000       0.009536    0.921511
# 1000       0.010329    0.914975
#
# [88 rows x 82 columns]

# %%
data_dict[commit].plot.scatter(x='X_nh3 initial',y='NH3(6) conversion (%)',label='NH3(6) conversion (%)',color="r")
# Out:
# <AxesSubplot:xlabel='X_nh3 initial', ylabel='NH3(6) conversion (%)'>

# %%
ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2(4) Selectivity (%)',
                                     label='N2',color="orange")
ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2O(7) Selectivity (%)',
                                     label='N2O',color='g', ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NO(5) Selectivity (%)',
                                     label='NO',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Selectivity (%)")
plt.show()

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='N2(4) Selectivity (%)',
                                     label='N2',color="orange")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N2O(7) Selectivity (%)',
                                     label='N2O',color='g', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='NO(5) Selectivity (%)',
                                     label='NO',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Selectivity (%)")
plt.show()

# %%
ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='OX Coverage',
                                     label='OX',color="orange")
ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='OHX Coverage',
                                     label='OHX',color='g', ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='X(1) Coverage',
                                     label='X',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage")
plt.show()

# %%
ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NOX Coverage',
                                     label='NO_X',color="r")
ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NX Coverage',
                                     label='N_X',color='orange', ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NH3X Coverage',
                                     label='NH3_X',color='b', ax=ax1)
ax4 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='X Coverage',
                                     label='X',color='g', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage")
plt.show()

# %% [markdown]
# ### For Rebrov's selectivity definitions:

# %%
for commit in commit_list:
    L5 = data_dict[commit]['NH3_X(8) + O_X(9) <=> NH2_X(10) + OH_X(11) ROP [kmol/m^2 s]']+data_dict[commit]['NH2_X(10) + O_X(9) <=> NH_X(12) + OH_X(11) ROP [kmol/m^2 s]']+data_dict[commit]['NH_X(12) + O_X(9) <=> N_X(13) + OH_X(11) ROP [kmol/m^2 s]']
    L6 = data_dict[commit]['2 N_X(13) <=> N2(4) + 2 X(1) ROP [kmol/m^2 s]']
    L7 =  data_dict[commit]['NO_X(14) + N_X(13) <=> N2O(7) + 2 X(1) ROP [kmol/m^2 s]']
    L12 = data_dict[commit]['NO_X(14) <=> NO(5) + X(1) ROP [kmol/m^2 s]']
    L13 = data_dict[commit]['N2O(7) + X(1) <=> N2(4) + O_X(9) ROP [kmol/m^2 s]'] 

    S_N2 = 2*(L6+L13)/L5
    S_N2O = 2*(L7-L13)/L5
    S_NO = 1*L12/L5
    data_dict[commit]['N2(4) Selectivity (%)'] = 100*S_N2 / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['NO(5) Selectivity (%)'] = 100*S_NO / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['N2O(7) Selectivity (%)'] = 100*S_N2O / (S_N2 + S_NO + S_N2O)

# data_dict[commit]['N2(4) Selectivity (%)']
# data_dict[commit]['NO(5) Selectivity (%)']
# data_dict[commit]['N2O(7) Selectivity (%)']

# %% [markdown]
# ### Use this if run RMG on master

# %%
for commit in commit_list:
    for i in conversion_species:
        data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
    
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])

    for i in coverage_species_1:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
    
    for i in coverage_species_2:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(64)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='OX(10) Coverage',
                                     label='O_X',color="orange")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='HOX(13) Coverage',
                                     label='OH_X',color='g', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='X(1) Coverage',
                                     label='X',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage (%)")
plt.show()

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='NO_ads(27) Coverage',
                                     label='NO_X',color="r")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N_ads(72) Coverage',
                                     label='N_X',color='orange', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='H3NX(29) Coverage',
                                     label='NH3_X',color='b', ax=ax1)
ax4 = data_dict[commit].plot(x='X_nh3 initial',y='X Coverage',
                                     label='X',color='g', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage (%)")
plt.show()
