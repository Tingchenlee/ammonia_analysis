# %%
import os
import glob
import itertools
from random import randint
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from pathlib import Path
import time

import matplotlib.cm as cm
from IPython.display import Image
import git

from rmgpy.molecule import Molecule
from rmgpy.data.base import Database

# %%
#Input file
rmg_model_path = '../ammonia/'
analysis_path = '../ammonia_analysis/results/no_gasrxn_results'

# %%
#Git-python: checkout master branch
import git
repo = git.Repo(rmg_model_path)
date = time.localtime(repo.head.commit.committed_date)
git_date = f"{date[0]}_{date[1]}_{date[2]}_{date[3]}{date[4]}"
git_sha = str(repo.head.commit)[0:6]
git_msg = str(repo.head.commit.message)[0:50].replace(" ", "_").replace("'", "_").replace("\n", "")

current_commit = f"{git_date}_{git_sha}_{git_msg}"

current_commit
# Out:
# '2021_6_15_1732_db1b46_training_no_gasrxn'

# %%
# #checkout 1 commit back
# repo.git.checkout('HEAD^1')
# sha = str(repo.head.commit)
# msg = str(repo.head.commit.message)
# print(sha,': ', msg)

# #checkout 2 commit back
# repo = git.Repo('/work/westgroup/lee.ting/cantera/ammonia/')
# repo.git.checkout('HEAD^1')
# sha = repo.head.commit
# msg = repo.head.commit.message
# print(sha,': ', msg)

# %%
commit_list = []

# read in each filename into dictionary. get a list of the commit folders in this repo
for path in Path(analysis_path).rglob('*.csv'):
    path_str = str(path)
    start_index = path_str.find(analysis_path)
    
    if start_index != -1:
        commit = path_str[(start_index+len(analysis_path)):]
        print(commit)
        if "\n" in commit:
            end_char = commit.index("\n")
        else: 
            end_char = commit.index("/")
        
        commit = commit[:end_char]
        if commit not in commit_list:
            commit_list.append(commit)
        
print(commit_list)
# Out:
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_011864406779661017.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_013728813559322034.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_015593220338983051.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_01745762711864407.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_019322033898305085.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_0211864406779661.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_02305084745762712.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_02491525423728814.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_026779661016949154.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_02864406779661017.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_03050847457627119.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_032372881355932207.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_03423728813559322.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_03610169491525424.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_03796610169491526.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_039830508474576275.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_04169491525423729.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_043559322033898305.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_04542372881355933.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_04728813559322034.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_04915254237288136.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_05101694915254238.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_052881355932203396.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_05474576271186441.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_056610169491525426.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_05847457627118644.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_060338983050847464.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_06220338983050848.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_0640677966101695.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_06593220338983051.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_06779661016949153.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_06966101694915254.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_07152542372881356.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_07338983050847457.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_07525423728813559.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_0771186440677966.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_07898305084745763.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_08084745762711865.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_08271186440677966.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_08457627118644068.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_08644067796610169.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_08830508474576271.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_09016949152542372.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_09203389830508475.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_09389830508474577.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_09576271186440678.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_0976271186440678.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_09949152542372881.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_10135593220338983.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_10322033898305084.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_10508474576271186.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_10694915254237287.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_1088135593220339.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_11067796610169492.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_11254237288135593.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_11440677966101695.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_11627118644067796.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_11813559322033898.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_1.58e-05_energy_off_temp_598_O2_0_NH3_0_12.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_011864406779661017.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_013728813559322034.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_015593220338983051.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_01745762711864407.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_019322033898305085.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_0211864406779661.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_02305084745762712.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_02491525423728814.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_026779661016949154.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_02864406779661017.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_03050847457627119.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_032372881355932207.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_03423728813559322.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_03610169491525424.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_03796610169491526.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_039830508474576275.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_04169491525423729.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_043559322033898305.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_04542372881355933.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_04728813559322034.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_04915254237288136.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_05101694915254238.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_052881355932203396.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_05474576271186441.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_056610169491525426.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_05847457627118644.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_060338983050847464.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_06220338983050848.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_0640677966101695.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_06593220338983051.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_06779661016949153.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_06966101694915254.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_07152542372881356.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_07338983050847457.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_07525423728813559.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_0771186440677966.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_07898305084745763.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_08084745762711865.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_08271186440677966.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_08457627118644068.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_08644067796610169.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_08830508474576271.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_09016949152542372.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_09203389830508475.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_09389830508474577.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_09576271186440678.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_0976271186440678.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_09949152542372881.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_10135593220338983.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_10322033898305084.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_10508474576271186.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_10694915254237287.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_1088135593220339.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_11067796610169492.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_11254237288135593.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_11440677966101695.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_11627118644067796.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_11813559322033898.csv
# /2021_6_15_1323_df9fd9_master_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598/results/Spinning_basket_area_7.92e-09_energy_off_temp_598_O2_0_NH3_0_12.csv
# ['']

# %%
data_dict = {}

# Read last line from each CSV file to get the outlet concentrations from the PFR
# if "one_commit" is true, only run the master commit 
one_commit = False
if one_commit == True:
    commit_list = [current_commit]
    f"/results/NH3_results/{git_file_string}/species_pictures"
for commit in commit_list:
    first_file = True
    #for path in Path('../ammonia_analysis/results/NH3_results/2021_6_14_1946_902d92_training_500_1000K_O88N066/IdealGasReactor/energy_off/sensitivity_off/598').rglob('*.csv'):
    for path in Path('../ammonia_analysis/results/no_gasrxn_results/2021_6_15_1323_df9fd9_master_500_1000K_O88N066').rglob('*.csv'):
        path_str = str(path)
        if os.stat(path_str).st_size >= 3e6:
            if first_file == True: 
                data = pd.read_csv(path_str)
                aggdata = data.tail(1)
                first_file = False
            else: 
                data = pd.read_csv(path_str)
                aggdata = aggdata.append(data.tail(1))
            data_dict.update({commit:aggdata})
        else:
            print(path_str)

# %% [markdown]
# ## Reproduce plots from Rebrov
#
# Rebrov, E. V., De Croon, M. H. J. M., & Schouten, J. C. (2002). Development of the kinetic model of platinum catalyzed ammonia oxidation in a microreactor. Chemical Engineering Journal, 90(1–2), 61–76. https://doi.org/10.1016/S1385-8947(02)00068-2
#
#
# for reference:
#
# ### $conversion(\%) = \frac{moles\_fed - moles\_out}{moles\_fed} $
#
# ### $selectivity(\%, N_2) = \frac{(2*r_{L6}+r_{L13})100}{r_{L5}} $
#
# ### $selectivity(\%, N_{2}O) = \frac{(2*r_{L7}-r_{L13})100}{r_{L5}} $

# %% [markdown]
# # For our selectivity definitions
# Two types of selectivity. Overall, and instantaneous.
#
# For overall selectivity, it depends on the total amounts exiting the packed bed. Probably what is measured experimentally from the PBR experiment (by measuring concentrations leaving the bed).
#
# $$ selectivity(N2) = \frac{2 * moles_{N2}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# The 2 is because we are preserving (and counting) atoms of Nitrogen. Selectivity is "What percentage of N atoms (from consuming ammonia) ended up as N2?
# "
#
# $$ selectivity(N2O) = \frac{2 * moles_{N2O}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# $$ selectivity(NO) = \frac{moles_{NO}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
#
#
# For instantaneous selectivity, it changes at different points in the packed bed.
# If we want the instantaneous selectivity evaluated at the exit of the bed, evaluate these expressions at the end of the bed (the last row):
#
# $$ selectivity(N2)  = \frac{ 2 * net rate of production of N2}{-1 * net rate of production of NH3}$$
# $$ selectivity(N2O)  = \frac{ 2 * net rate of production of N2O}{-1 * net rate of production of NH3}$$
# $$ selectivity(NO)  = \frac{  net rate of production of NO}{-1 * net rate of production of NH3}$$

# %%
Image('Images/Rebrov_table2.png')

# %%
# for commit in commit_list:
#     data_dict[commit]['H3NX(29) + 3OX(10) <=> N_ads(64) + 3HOX(13)  ROP [kmol/m^2 s]'] = data_dict[commit]['H3NX(29) + OX(10) <=> H2NX(28) + HOX(13) ROP [kmol/m^2 s]'] + data_dict[commit]['H2NX(28) + OX(10) <=> HOX(13) + NH_ads(51) ROP [kmol/m^2 s]'] + data_dict[commit]['NH_ads(51) + OX(10) <=> HOX(13) + N_ads(64) ROP [kmol/m^2 s]']
# L5 = ['H3NX(29) + 3OX(10) <=> N_ads(64) + 3HOX(13)  ROP [kmol/m^2 s]']
# L6 = ['N2(4) + 2 X(1) <=> N2X2(25) ROP [kmol/m^2 s]'] #L6 is missing in master
# L7 = [''] #L7 is missing in master
# L13 = [''] #L7 is missing in master

# %% [markdown]
# ### Figure 3
# #### create partial pressure, selectivity, and concentration columns in the dataframe

# %%
#choose species partial pressures (for X-axis of plots) 
x_axis_nh3 = ['NH3(6)']

conversion_species = ['NH3(6) ROP [kmol/m^3 s]']
#selectivity_species = ['N2(4)','N2O(7)','NO(5)']
selectivity_species = ['N2(4) ROP [kmol/m^3 s]','NO(5) ROP [kmol/m^3 s]','N2O(7) ROP [kmol/m^3 s]']
# this is H-site adsorption. no way to tell that from cantera 
#coverage_species_1 = ['OX(10)', 'HOX(13)', 'X(1)'] 
coverage_species_1 = ['O_X(9)', 'OH_X(11)', 'X(1)'] 

# this is N-site adsorption. no way to tell that from cantera
coverage_species_2 = ['NO_X(14)', 'N_X(13)', 'NH3_X(8)', 'X(1)']
#coverage_species_2 = ['NO_ads(27)', 'N_ads(64)', 'H3NX(29)', 'X(1)']
#coverage_species_2 = ['NO_X(24)', 'N_X(23)', 'NH3_X(22)', 'X(1)'] # for training_673K_all_families_and_Pt_libraries

# %%
for commit in commit_list:
    data_dict[commit]['NH3(6) conversion (%)']= 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])/data_dict[commit]['X_nh3 initial']
   
    S_N2 = (-2)*(data_dict[commit]['N2(4) surface ROP [kmol/m^2 s]'])/data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']
    S_NO = (-1)*(data_dict[commit]['NO(5) surface ROP [kmol/m^2 s]'])/data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']
    S_N2O = (-2)*(data_dict[commit]['N2O(7) surface ROP [kmol/m^2 s]'])/data_dict[commit]['NH3(6) surface ROP [kmol/m^2 s]']
    data_dict[commit]['N2(4) Selectivity (%)'] = 100*S_N2 / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['NO(5) Selectivity (%)'] = 100*S_NO / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['N2O(7) Selectivity (%)'] = 100*S_N2O / (S_N2 + S_NO + S_N2O)

    data_dict[commit]['O_X(9) Coverage']=data_dict[commit]['O_X(9)']/(data_dict[commit]['O_X(9)'] + data_dict[commit]['OH_X(11)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['OH_X(11) Coverage']=data_dict[commit]['OH_X(11)']/(data_dict[commit]['O_X(9)'] + data_dict[commit]['OH_X(11)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['X(1) Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['O_X(9)'] + data_dict[commit]['OH_X(11)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['NO_X(14) Coverage']=data_dict[commit]['NO_X(14)']/(data_dict[commit]['NO_X(14)'] + data_dict[commit]['N_X(13)']+ data_dict[commit]['NH3_X(8)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['N_X(13) Coverage']=data_dict[commit]['N_X(13)']/(data_dict[commit]['NO_X(14)'] + data_dict[commit]['N_X(13)']+ data_dict[commit]['NH3_X(8)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['NH3_X(8) Coverage']=data_dict[commit]['NH3_X(8)']/(data_dict[commit]['NO_X(14)'] + data_dict[commit]['N_X(13)']+ data_dict[commit]['NH3_X(8)']+ data_dict[commit]['X(1)'])
    data_dict[commit]['X Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['NO_X(14)'] + data_dict[commit]['N_X(13)']+ data_dict[commit]['NH3_X(8)']+ data_dict[commit]['X(1)'])

# %%
# for commit in commit_list:
#     data_dict[commit]['NH3(6) conversion (%)']= 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])/data_dict[commit]['X_nh3 initial']
   
#     S_N2 = (-2)*(data_dict[commit]['N2(4) ROP [kmol/m^3 s]'])/data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']
#     S_NO = (-1)*(data_dict[commit]['NO(5) ROP [kmol/m^3 s]'])/data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']
#     S_N2O = (-2)*(data_dict[commit]['N2O(7) ROP [kmol/m^3 s]'])/data_dict[commit]['NH3(6) ROP [kmol/m^3 s]']
#     data_dict[commit]['N2(4) Selectivity (%)'] = 100*S_N2 / (S_N2 + S_NO + S_N2O)
#     data_dict[commit]['NO(5) Selectivity (%)'] = 100*S_NO / (S_N2 + S_NO + S_N2O)
#     data_dict[commit]['N2O(7) Selectivity (%)'] = 100*S_N2O / (S_N2 + S_NO + S_N2O)

#     data_dict[commit]['OX(10) Coverage']=data_dict[commit]['OX(10)']/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['HOX(13) Coverage']=data_dict[commit]['HOX(13)']/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['X(1) Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['NO_ads(27) Coverage']=data_dict[commit]['NO_ads(27)']/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(72)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['N_ads(72) Coverage']=data_dict[commit]['N_ads(72)']/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(72)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['H3NX(29) Coverage']=data_dict[commit]['H3NX(29)']/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(72)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])
#     data_dict[commit]['X Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(72)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])

# %%
# for commit in commit_list:
#     for i in conversion_species:
#         data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
    
#     for i in selectivity_species:
#         data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])

#     for i in coverage_species_1:
#         data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
    
#     for i in coverage_species_2:
#         data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(64)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])

# %%
# for commit in commit_list:
#     for i in conversion_species:
#         data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
    
#     for i in selectivity_species:
#         data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])

#     for i in coverage_species_1:
#         data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
    
#     for i in coverage_species_2:
#         data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['NO_X(24)'] + data_dict[commit]['N_X(23)']+ data_dict[commit]['NH3_X(22)']+ data_dict[commit]['X(1)'])

# %%
data_dict[commit]['NH3(6) conversion (%)']
# Out:
# 1000    1.615632e-09
# 1000    1.712685e-09
# 1000    1.818514e-09
# 1000    1.926123e-09
# 1000    2.034889e-09
#             ...
# 1000    1.689370e-12
# 1000    1.880183e-12
# 1000    1.790356e-12
# 1000    2.983824e-12
# 1000    2.058539e-12
# Name: NH3(6) conversion (%), Length: 118, dtype: float64

# %%
data_dict[commit].to_csv("rebrov_no_gasrxn_data.csv")
data_dict[commit]
# Out:
#       Distance (mm)  T (K)    P (Pa)  V (M^3/s)  X_nh3 initial  X_o2 initial  \
# 1000            9.0    598  101325.0   0.000058       0.011864          0.88
# 1000            9.0    598  101325.0   0.000058       0.013729          0.88
# 1000            9.0    598  101325.0   0.000058       0.015593          0.88
# 1000            9.0    598  101325.0   0.000058       0.017458          0.88
# 1000            9.0    598  101325.0   0.000058       0.019322          0.88
# ...             ...    ...       ...        ...            ...           ...
# 1000            9.0    598  101325.0   0.000058       0.112542          0.88
# 1000            9.0    598  101325.0   0.000058       0.114407          0.88
# 1000            9.0    598  101325.0   0.000058       0.116271          0.88
# 1000            9.0    598  101325.0   0.000058       0.118136          0.88
# 1000            9.0    598  101325.0   0.000058       0.120000          0.88
#
#       X_he initial  (NH3/O2)  T (K) final          Rtol  ...  \
# 1000      0.108136  0.013482        598.0  1.000000e-11  ...
# 1000      0.106271  0.015601        598.0  1.000000e-11  ...
# 1000      0.104407  0.017720        598.0  1.000000e-11  ...
# 1000      0.102542  0.019838        598.0  1.000000e-11  ...
# 1000      0.100678  0.021957        598.0  1.000000e-11  ...
# ...            ...       ...          ...           ...  ...
# 1000      0.007458  0.127889        598.0  1.000000e-11  ...
# 1000      0.005593  0.130008        598.0  1.000000e-11  ...
# 1000      0.003729  0.132126        598.0  1.000000e-11  ...
# 1000      0.001864  0.134245        598.0  1.000000e-11  ...
# 1000      0.000000  0.136364        598.0  1.000000e-11  ...
#
#       N2(4) Selectivity (%) NO(5) Selectivity (%) N2O(7) Selectivity (%)  \
# 1000           4.256377e-09             99.999720               0.000280
# 1000           5.226535e-09             99.999675               0.000325
# 1000           6.296919e-09             99.999630               0.000370
# 1000           7.455726e-09             99.999585               0.000415
# 1000           8.734283e-09             99.999540               0.000460
# ...                     ...                   ...                    ...
# 1000           2.282196e-07             99.997130               0.002870
# 1000           2.359673e-07             99.997078               0.002922
# 1000           2.439642e-07             99.997025               0.002975
# 1000           2.520514e-07             99.996972               0.003028
# 1000           2.602830e-07             99.996919               0.003081
#
#       O_X(9) Coverage  OH_X(11) Coverage  X(1) Coverage  NO_X(14) Coverage  \
# 1000              1.0       8.411687e-14   3.136672e-08           0.007625
# 1000              1.0       9.322152e-14   3.328038e-08           0.008823
# 1000              1.0       1.022826e-13   3.526067e-08           0.010011
# 1000              1.0       1.113365e-13   3.730292e-08           0.011213
# 1000              1.0       1.204064e-13   3.940248e-08           0.012388
# ...               ...                ...            ...                ...
# 1000              1.0       6.129559e-13   1.709882e-07           0.068161
# 1000              1.0       6.232003e-13   1.737801e-07           0.069226
# 1000              1.0       6.336245e-13   1.766662e-07           0.070297
# 1000              1.0       6.439790e-13   1.795116e-07           0.071363
# 1000              1.0       6.543475e-13   1.823618e-07           0.072426
#
#       N_X(13) Coverage  NH3_X(8) Coverage  X Coverage
# 1000          0.000457           0.001106    0.990812
# 1000          0.000528           0.001278    0.989372
# 1000          0.000599           0.001449    0.987941
# 1000          0.000670           0.001620    0.986497
# 1000          0.000741           0.001791    0.985080
# ...                ...                ...         ...
# 1000          0.004142           0.009719    0.917978
# 1000          0.004207           0.009866    0.916700
# 1000          0.004273           0.010013    0.915417
# 1000          0.004338           0.010159    0.914140
# 1000          0.004403           0.010305    0.912866
#
# [118 rows x 166 columns]

# %%
data_dict[commit].plot.scatter(x='X_nh3 initial',y='NH3(6) conversion (%)',label='NH3(6) conversion (%)',color="r")
# Out:
# <AxesSubplot:xlabel='X_nh3 initial', ylabel='NH3(6) conversion (%)'>

# %%
ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2(4) Selectivity (%)',
                                     label='N2',color="orange")
ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N2O(7) Selectivity (%)',
                                     label='N2O',color='g', ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NO(5) Selectivity (%)',
                                     label='NO',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Selectivity (%)")
plt.show()

# %%
# ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='O_X(9) Coverage',
#                                      label='O_X',color="orange")
# ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='OH_X(11) Coverage',
#                                      label='OH_X',color='g', ax=ax1)
# ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='X(1) Coverage',
#                                      label='X',color='blue', ax=ax1)
# ax1.set_xlabel("NH3(6) partial pressure (atm)")
# ax1.set_ylabel("Coverage (%)")
# plt.show()

ax1 = data_dict[commit].plot(x='X_nh3 initial',y='O_X(9) Coverage',
                                     label='O_X',color="orange")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='OH_X(11) Coverage',
                                     label='OH_X',color='g', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='X(1) Coverage',
                                     label='X',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage (%)")
plt.show()
# ax1 = data_dict[commit].plot(x='X_nh3 initial',y='OX(10) Coverage',
#                                      label='O_X',color="orange")
# ax2 = data_dict[commit].plot(x='X_nh3 initial',y='HOX(13) Coverage',
#                                      label='OH_X',color='g', ax=ax1)
# ax3 = data_dict[commit].plot(x='X_nh3 initial',y='X(1) Coverage',
#                                      label='X',color='blue', ax=ax1)
# ax1.set_xlabel("NH3(6) partial pressure (atm)")
# ax1.set_ylabel("Coverage (%)")
# plt.show()

# %%
# ax1 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NO_X(14) Coverage',
#                                      label='NO_X',color="r")
# ax2 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='N_X(13) Coverage',
#                                      label='N_X',color='orange', ax=ax1)
# ax3 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='NH3_X(8) Coverage',
#                                      label='NH3_X',color='b', ax=ax1)
# ax4 = data_dict[commit].plot.scatter(x='X_nh3 initial',y='X(1) Coverage',
#                                      label='X',color='g', ax=ax1)
# ax1.set_xlabel("NH3(6) partial pressure (atm)")
# ax1.set_ylabel("Coverage (%)")
# plt.show()
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='NO_X(14) Coverage',
                                     label='NO_X',color="r")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N_X(13) Coverage',
                                     label='N_X',color='orange', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='NH3_X(8) Coverage',
                                     label='NH3_X',color='b', ax=ax1)
ax4 = data_dict[commit].plot(x='X_nh3 initial',y='X Coverage',
                                     label='X',color='g', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage")
plt.show()
# ax1 = data_dict[commit].plot(x='X_nh3 initial',y='NO_ads(27) Coverage',
#                                      label='NO_X',color="r")
# ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N_ads(72) Coverage',
#                                      label='N_X',color='orange', ax=ax1)
# ax3 = data_dict[commit].plot(x='X_nh3 initial',y='H3NX(29) Coverage',
#                                      label='NH3_X',color='b', ax=ax1)
# ax4 = data_dict[commit].plot(x='X_nh3 initial',y='X Coverage',
#                                      label='X',color='g', ax=ax1)
# ax1.set_xlabel("NH3(6) partial pressure (atm)")
# ax1.set_ylabel("Coverage (%)")
# plt.show()

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    
selectivity_species = [df_698K['NO(5) Selectivity (%)'],df_698K['N2O(7) Selectivity (%)'],df_698K['N2(4) Selectivity (%)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-15016da16e9e> in <module>
#       2     data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
#       3
# ----> 4 selectivity_species = [df_698K['NO(5) Selectivity (%)'],df_698K['N2O(7) Selectivity (%)'],df_698K['N2(4) Selectivity (%)']]
#
# NameError: name 'df_698K' is not defined

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    nh3_pressure = data_dict[commit][f'NH3(6) partial pressure (atm)']

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
        selectivity = data_dict[commit][f'{i} Selectivity (%)']
        print(selectivity[0:108])
#         fig, ax = plt.subplots(len(selectivity),1,figsize=(10,30), constrained_layout = True)
#         color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
            
#         for p,j in enumerate(selectivity):
#             data_dict[commit][(data_dict[commit][f'{i} Selectivity (%)'] == j) &
#                              (data_dict[commit]['T (K)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
#                                                                                  y=selectivity[0:3], 
#                                                                                  label='NH3(6) conversion (%)', 
#                                                                                  ax=ax[p], 
#                                                                                  color="r")

#             ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')
# Out:
# 1000    49.751244
# 1000    49.627792
# 1000    49.504950
# 1000    49.382716
# 1000    49.261084
#           ...
# 1000    49.028205
# 1000    48.899749
# 1000    48.780482
# 1000    48.661795
# 1000    48.543685
# Name: N2(4) Selectivity (%), Length: 107, dtype: float64
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
#        ...
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# Name: N2O(7) Selectivity (%), Length: 107, dtype: float64
# 1000    8.623474e-08
# 1000    7.827234e-08
# 1000    7.398438e-08
# 1000    7.124887e-08
# 1000    6.932246e-08
#             ...
# 1000    1.466004e-05
# 1000    1.286029e-05
# 1000    1.143953e-05
# 1000    1.029474e-05
# 1000    9.352290e-06
# Name: NO(5) Selectivity (%), Length: 107, dtype: float64

# %% [markdown]
# #### Selectivity and Coverage

# %%
for commit in commit_list:
    data_dict[commit]['NO selectivity (%)'] = 100*(data_dict[commit]['NO(5)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['NO selectivity (%)'])
    no_selectivity = data_dict[commit]['NO selectivity (%)'] 

    data_dict[commit]['N2O selectivity (%)'] = 100*(data_dict[commit]['N2O(7)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['N2O selectivity (%)'])
    n2o_selectivity = data_dict[commit]['N2O selectivity (%)']

    data_dict[commit]['N2 selectivity (%)'] = 100*(data_dict[commit]['N2(4)'])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    #print(data_dict[commit]['N2 selectivity (%)'])
    n2_selectivity = data_dict[commit]['N2 selectivity (%)']

    S_N2 = n2_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100
    S_NO = no_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100
    S_N2O = n2o_selectivity/(n2_selectivity + no_selectivity + n2o_selectivity)*100

# %% [markdown]
# #### NH3 initial partial pressure

# %%
for commit in commit_list:
    data_dict[commit][f'NH3(6) partial pressure (atm)'] =  data_dict[commit]['X_nh3 initial']*data_dict[commit]['P (Pa)']/101325
    nh3_pressure = data_dict[commit][f'NH3(6) partial pressure (atm)']

# %%
nh3_pressure
# Out:
# 1000    0.02
# 1000    0.03
# 1000    0.04
# 1000    0.05
# 1000    0.06
#         ...
# 1000    0.08
# 1000    0.09
# 1000    0.10
# 1000    0.11
# 1000    0.12
# Name: NH3(6) partial pressure (atm), Length: 107, dtype: float64

# %%
for i in selectivity_species:
    data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
    print(data_dict[commit][f'{i} Selectivity (%)'])
# Out:
# 1000    49.751244
# 1000    49.627792
# 1000    49.504950
# 1000    49.382716
# 1000    49.261084
#           ...
# 1000    49.028205
# 1000    48.899749
# 1000    48.780482
# 1000    48.661795
# 1000    48.543685
# Name: N2(4) Selectivity (%), Length: 107, dtype: float64
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
#        ...
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# 1000    0.0
# Name: N2O(7) Selectivity (%), Length: 107, dtype: float64
# 1000    8.623474e-08
# 1000    7.827234e-08
# 1000    7.398438e-08
# 1000    7.124887e-08
# 1000    6.932246e-08
#             ...
# 1000    1.466004e-05
# 1000    1.286029e-05
# 1000    1.143953e-05
# 1000    1.029474e-05
# 1000    9.352290e-06
# Name: NO(5) Selectivity (%), Length: 107, dtype: float64

# %%
for commit in commit_list:
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])    
        selectivityNO = data_dict[commit][f'{i} Selectivity (%)']#.unique()
        selectivityN2O = data_dict[commit][f'{i+1} Selectivity (%)']
       # print(selectivity)
        plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
        plt.plot(nh3_pressure[0:10], selectivityNO[0:10],nh3_pressure[0:10], selectivityN2O[0:10])
        plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
        plt.ylabel(f'{i} Selectivity (%)',fontsize=15)
        plt.minorticks_on()
        plt.grid(b=True, which='minor', color='beige', alpha=0.8, ls='-', lw=1)
        plt.title(f'{commit} \ntemperature {temp}',fontsize=15)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-07048fb0ec41> in <module>
#       3         data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])
#       4         selectivityNO = data_dict[commit][f'{i} Selectivity (%)']#.unique()
# ----> 5         selectivityN2O = data_dict[commit][f'{i+1} Selectivity (%)']
#       6        # print(selectivity)
#       7         plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
for commit in commit_list:
    
    for temp in temps:
        # get keys for O2 (X_o2 initial)
        o2_ratio = data_dict[commit_list[0]]['O2(2) partial pressure (atm)'].unique()

        # set figure size 
        fig, ax = plt.subplots(len(o2_ratio),1,figsize=(10,30), constrained_layout = True)

        # make a list of markers
        color_dict = { 0:"r", 1:"gold", 2:"pink", 3:"yellowgreen",4:"lightskyblue"}
    
        for p,j in enumerate(o2_ratio):
            data_dict[commit][(data_dict[commit]['O2(2) partial pressure (atm)'] == j) &
                             (data_dict[commit]['T (C)'] == temp)].plot.scatter(x='NH3(6) partial pressure (atm)', 
                                                                                 y='NH3(6) conversion (%)', 
                                                                                 label='NH3(6) conversion (%)', 
                                                                                 ax=ax[p], 
                                                                                 color="r")

            ax[p].set_title(f'{commit} \nmole frac O2 = {j} \ntemperature {temp}')

# %%
df_t_225_02_0_88_data_dict=data_dict[commit][(data_dict[commit]['O2(2) partial pressure (atm)'] == 0.88) &
                             (data_dict[commit]['T (C)'] == 225)]

# %%
df_t_225_02_0_88_data_dict
# Out:
#      Distance (mm)  T (C)    P (Pa)     V (M^3/s)  X_nh3 initial  \
# 921         8280.0    225  101325.0  2.715500e-08          0.010
# 235         2106.0    225  101325.0  2.715500e-08          0.020
# 420         3771.0    225  101325.0  2.715500e-08          0.025
# 98           873.0    225  101325.0  2.715500e-08          0.070
#
#      X_o2 initial  X_he initial  (NH3/O2)  T (C) final          Rtol  ...  \
# 921          0.88         0.110  0.011364        225.0  1.000000e-08  ...
# 235          0.88         0.100  0.022727        225.0  1.000000e-08  ...
# 420          0.88         0.095  0.028409        225.0  1.000000e-08  ...
# 98           0.88         0.050  0.079545        225.0  1.000000e-08  ...
#
#      HNOX(136) + NO2X2(466) <=> NO_X(26) + SX(146) ROP [kmol/m^2 s]  \
# 921                                      -5.168881e-72
# 235                                       1.829502e-59
# 420                                       2.851775e-47
# 98                                        1.661289e-72
#
#     SX(146) + X(1) <=> HOX(13) + NOX2(132) ROP [kmol/m^2 s].1  \
# 921                                       3.417907e-61
# 235                                      -2.670272e-57
# 420                                       1.011025e-50
# 98                                        0.000000e+00
#
#     N_X(25) + SX(146) <=> HNOX(136) + NOX2(132) ROP [kmol/m^2 s].2  \
# 921                                       2.962649e-47
# 235                                      -3.464858e-43
# 420                                       1.509520e-36
# 98                                        0.000000e+00
#
#      N_X(25) + SX(146) <=> HNOX(136) + NOX2(132) ROP [kmol/m^2 s].3  \
# 921                                       2.962649e-47
# 235                                      -3.464858e-43
# 420                                       1.509520e-36
# 98                                        0.000000e+00
#
#      NO2(30) + 2 X(1) <=> NO2X2(248) ROP [kmol/m^2 s]  \
# 921                                      6.222660e-58
# 235                                     -3.819620e-65
# 420                                      2.184174e-54
# 98                                      -7.709948e-74
#
#      NO2X2(248) + OX(10) <=> NOX2(132) + O2X(731) ROP [kmol/m^2 s]  \
# 921                                       4.630594e-58
# 235                                      -2.691550e-66
# 420                                       4.229134e-55
# 98                                        3.998287e-70
#
#      NH3(6) conversion (%)  NO(5) selectivity (%)  \
# 921           2.585369e-06           1.515396e-29
# 235          -1.309972e-05          -5.140747e-38
# 420          -2.642432e-06          -5.146292e-36
# 98           -1.745461e-07          -4.312019e-35
#
#      NH3(6) partial pressure (atm)  O2(2) partial pressure (atm)
# 921                          0.010                          0.88
# 235                          0.020                          0.88
# 420                          0.025                          0.88
# 98                           0.070                          0.88
#
# [4 rows x 465 columns]

# %%
df_t_225_02_0_88_data_dict.plot.scatter(x='NH3(6) partial pressure (atm)', 
                                        y='NH3(6) conversion (%)', 
                                        label='NH3(6) conversion (%)', 
                                        color="r")
# Out:
# <AxesSubplot:xlabel='NH3(6) partial pressure (atm)', ylabel='NH3(6) conversion (%)'>

# %%
#If set up different temp ranges
df_498K = data_dict[commit][data_dict[commit]['T (K)'] == 498]
df_523K = data_dict[commit][data_dict[commit]['T (K)'] == 523]
df_548K = data_dict[commit][data_dict[commit]['T (K)'] == 548]
df_573K = data_dict[commit][data_dict[commit]['T (K)'] == 573]
df_598K = data_dict[commit][data_dict[commit]['T (K)'] == 598]
df_623K = data_dict[commit][data_dict[commit]['T (K)'] == 623]
df_648K = data_dict[commit][data_dict[commit]['T (K)'] == 648]
df_698K = data_dict[commit][data_dict[commit]['T (K)'] == 698]

fig = plt.figure()
ax = plt.axes()
#plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
plt.plot(df_698K['X_nh3 initial'], df_698K['N2(4) Selectivity (%)'], label = 'N2')
plt.plot(df_698K['X_nh3 initial'], df_698K['N2O(7) Selectivity (%)'], label = 'N2O')
plt.plot(df_698K['X_nh3 initial'], 1e5*df_698K['NO(5) Selectivity (%)'], label = 'NO')
plt.xlabel('NH3')
plt.ylabel('Selectivity')
plt.title('X_NH3 v.s. Selectivity Plot ')
plt.legend()

plt.grid(b=True, which='major', color='gray', alpha=0.6, linestyle='dashdot', lw=1.5)
plt.plot(nh3_pressure[0:11], 1e5*no_selectivity[96:107],label= "NO*e5")
plt.plot(nh3_pressure[0:11], 1e5*n2o_selectivity[96:107],label= "N2O*e5")
plt.plot(nh3_pressure[0:11], n2_selectivity[96:107],label= "N2")
plt.xlabel('NH3(6) partial pressure (atm)',fontsize=15)
plt.ylabel('Selectivity (%)',fontsize=15)
plt.minorticks_on()
plt.title('Temperature = 698K' ,fontsize=15)
plt.legend()

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
type(surf.forward_rate_constants)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4293126c212c> in <module>
# ----> 1 type(surf.forward_rate_constants)
#
# NameError: name 'surf' is not defined

# %%
surf_rates = {}
for i,j in enumerate(surf.reaction_equations()):
    surf_rates[j]=surf.reverse_rate_constants[i]
{k: v for k, v in sorted(surf_rates.items(), key=lambda item: item[1], reverse=True)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-fb5cb793406e> in <module>
#       1 surf_rates = {}
# ----> 2 for i,j in enumerate(surf.reaction_equations()):
#       3     surf_rates[j]=surf.reverse_rate_constants[i]
#       4 {k: v for k, v in sorted(surf_rates.items(), key=lambda item: item[1], reverse=True)}
#
# NameError: name 'surf' is not defined
